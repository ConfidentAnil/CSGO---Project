# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('DataCSGO.csv')

# %%
df
# Out:
#         time_left  ct_score  t_score       map  bomb_planted  ct_health  \
# 0          175.00         0        0  de_dust2         False        500
# 1          156.03         0        0  de_dust2         False        500
# 2           96.03         0        0  de_dust2         False        391
# 3           76.03         0        0  de_dust2         False        391
# 4          174.97         1        0  de_dust2         False        500
# ...           ...       ...      ...       ...           ...        ...
# 115390      66.91         9        4  de_train         False        439
# 115391      46.91         9        4  de_train         False        439
# 115392      26.92         9        4  de_train         False        339
# 115393      36.33         9        4  de_train          True        100
# 115394      16.33         9        4  de_train          True        100
#
#         t_health  ct_armor  t_armor  ct_money  ...  t_grenade_flashbang  \
# ...

# %%
df.shape
# Out:
# (115395, 97)

# %%
df.columns
# Out:
# Index(['time_left', 'ct_score', 't_score', 'map', 'bomb_planted', 'ct_health',
#        't_health', 'ct_armor', 't_armor', 'ct_money', 't_money', 'ct_helmets',
#        't_helmets', 'ct_defuse_kits', 'ct_players_alive', 't_players_alive',
#        'ct_weapon_ak47', 't_weapon_ak47', 'ct_weapon_aug', 't_weapon_aug',
#        'ct_weapon_awp', 't_weapon_awp', 'ct_weapon_bizon', 't_weapon_bizon',
#        'ct_weapon_cz75auto', 't_weapon_cz75auto', 'ct_weapon_elite',
#        't_weapon_elite', 'ct_weapon_famas', 't_weapon_famas',
#        'ct_weapon_g3sg1', 't_weapon_g3sg1', 'ct_weapon_galilar',
#        't_weapon_galilar', 'ct_weapon_glock', 't_weapon_glock',
#        'ct_weapon_m249', 't_weapon_m249', 'ct_weapon_m4a1s', 't_weapon_m4a1s',
#        'ct_weapon_m4a4', 't_weapon_m4a4', 'ct_weapon_mac10', 't_weapon_mac10',
#        'ct_weapon_mag7', 't_weapon_mag7', 'ct_weapon_mp5sd', 't_weapon_mp5sd',
#        'ct_weapon_mp7', 't_weapon_mp7', 'ct_weapon_mp9', 't_weapon_mp9',
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 115395 entries, 0 to 115394
# Data columns (total 97 columns):
#  #   Column                        Non-Null Count   Dtype
# ---  ------                        --------------   -----
#  0   time_left                     115395 non-null  float64
#  1   ct_score                      115395 non-null  int64
#  2   t_score                       115395 non-null  int64
#  3   map                           115395 non-null  object
#  4   bomb_planted                  115395 non-null  bool
#  5   ct_health                     115395 non-null  int64
#  6   t_health                      115395 non-null  int64
#  7   ct_armor                      115395 non-null  int64
#  8   t_armor                       115395 non-null  int64
#  9   ct_money                      115395 non-null  int64
#  10  t_money                       115395 non-null  int64
#  11  ct_helmets                    115395 non-null  int64
# ...

# %%
df.duplicated().sum()
# Out:
# np.int64(4513)

# %%
df.drop_duplicates(inplace= True)

# %%
col = ['map', 'bomb_planted']
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
for i in col:
    df[i] = le.fit_transform(df[i])

# %%
x = df.iloc[:, :-1]
y = df.iloc[:, -1]

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.2, random_state=0)

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()

# %%
x_train_std = sc.fit_transform(x_train)
x_test_std = sc.fit_transform(x_test)

# %%
x_train_std.shape
# Out:
# (88705, 96)

# %%
x_test_std.shape
# Out:
# (22177, 96)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
lr = LogisticRegression()
lr.fit(x_train_std, y_train)
y_pred = lr.predict(x_test_std)
accuracy_score(y_pred, y_test)
# Out:
# 0.7571357712945844

# %%
from sklearn.ensemble import RandomForestClassifier
rfc= RandomForestClassifier()
rfc.fit(x_train_std, y_train)
y_pred_rfc = rfc.predict(x_test_std)
accuracy_score(y_pred, y_test)
# Out:
# 0.7571357712945844

# %%
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis

# %%
lda = LinearDiscriminantAnalysis(n_components=1)
lda.fit(x_train_std, y_train)
# Out:
# LinearDiscriminantAnalysis(n_components=1)

# %%
ldacoef = np.abs(lda.coef_)
ldacoef = ldacoef.flatten()

# %%
coef_df = pd.DataFrame()
coef_df['Column Name'] = x.columns
coef_df['Coef Value'] = ldacoef

# %%
coef_df.sort_values(by = 'Coef Value', ascending = False)
# Out:
#              Column Name    Coef Value
# 8                t_armor  6.377787e-01
# 17         t_weapon_ak47  6.111470e-01
# 7               ct_armor  5.982624e-01
# 65        t_weapon_sg553  5.571599e-01
# 40        ct_weapon_m4a4  4.671468e-01
# ..                   ...           ...
# 52       ct_weapon_negev  8.953596e-16
# 30       ct_weapon_g3sg1  8.083544e-16
# 58  ct_weapon_r8revolver  4.246250e-16
# 60    ct_weapon_sawedoff  4.243933e-16
# 22       ct_weapon_bizon  1.031839e-16
#
# [96 rows x 2 columns]

# %%
new_feature_20 = coef_df.nlargest(20, columns='Coef Value')

# %%
new_feature_20
# Out:
#                Column Name  Coef Value
# 8                  t_armor    0.637779
# 17           t_weapon_ak47    0.611147
# 7                 ct_armor    0.598262
# 65          t_weapon_sg553    0.557160
# 40          ct_weapon_m4a4    0.467147
# 5                ct_health    0.454786
# 15         t_players_alive    0.416984
# 6                 t_health    0.325348
# 20           ct_weapon_awp    0.315794
# 21            t_weapon_awp    0.254585
# 4             bomb_planted    0.244380
# 89  t_grenade_smokegrenade    0.243091
# 14        ct_players_alive    0.217044
# 35          t_weapon_glock    0.212430
# 64         ct_weapon_sg553    0.212210
# 9                 ct_money    0.207892
# 16          ct_weapon_ak47    0.192517
# 18           ct_weapon_aug    0.192516
# 87     t_grenade_flashbang    0.179587
# 10                 t_money    0.165597

# %%
new_feature_20.index
# Out:
# Index([8, 17, 7, 65, 40, 5, 15, 6, 20, 21, 4, 89, 14, 35, 64, 9, 16, 18, 87,
#        10],
#       dtype='int64')

# %%
new_feature_20.columns
# Out:
# Index(['Column Name', 'Coef Value'], dtype='object')

# %%
lda_x = df.iloc[:, [8, 17, 7, 65, 40, 5, 15, 6, 20, 21, 89, 4, 64, 14, 9, 18, 16, 87, 35, 10]]
lda_y = df.iloc[:,-1]

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(lda_x, lda_y, test_size = 0.2, random_state = 0)

# %%
from sklearn.linear_model import LogisticRegression
model_lg = LogisticRegression()
model_lg.fit(x_train, y_train)
# Out:
# c:\Users\anilk\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
y_pred_lg = model_lg.predict(x_test)

# %%
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
accuracy_score(y_pred_lg, y_test)
# Out:
# 0.7443748027235424

# %%
from sklearn.tree import DecisionTreeClassifier
dtc = DecisionTreeClassifier()
dtc.fit(x_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
y_pred_dtc = dtc.predict(x_test)

# %%
accuracy_score(y_pred_dtc, y_test)
# Out:
# 0.8058348739685259

# %%
from sklearn.ensemble import RandomForestClassifier
rfc= RandomForestClassifier()
rfc.fit(x_train, y_train)
# Out:
# RandomForestClassifier()

# %%
y_pred_rfc = rfc.predict(x_test)
accuracy_score(y_pred_rfc, y_test)
# Out:
# 0.8542183343103215

# %% [markdown]
# Findings :
#
# ** After using feature reduction technique like LDA we are able to bring down the features to 20 features and accuracy is improved a good extent **
